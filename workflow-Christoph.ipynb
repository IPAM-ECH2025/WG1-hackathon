# %%
import sys
sys.path.append ("/home/cfreysoldt/pyiron_core/")

# %%
import pyiron_core as pc
pf = pc.PyironFlow(
    [
        "image-charge",
    ],
    workflow_path="workflows",
)
pf.gui_layout.flow_widget_height=400

pf.gui
# Out:
# /home/cfreysoldt/miniforge3/envs/pyiron_core/lib/python3.12/site-packages/nglview/__init__.py:12: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# ...
